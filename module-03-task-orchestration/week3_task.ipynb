# %% [markdown]
# # Question 1

# %% [markdown]
# **Answer:** AI Copilot has access to current Kestra plugin documentation

# %% [markdown]
# # Question 2

# %% [markdown]
# **Answer:** Vague, generic, or fabricated — the model guesses from training data

# %% [markdown]
# # Question 3

# %% [markdown]
#  Output tokens: 64
#
# **Answer:** 60-100 tokens

# %% [markdown]
# # Question 4

# %% [markdown]
#  Output tokens: 223
#
# Ratio = 223 / 64 ≈ 3.48x more
#
# **Answer:** 2-5x more

# %% [markdown]
# # Question 5

# %% [markdown]
# - Output tokens: 47 [prompt asking for exactly 1 sentence]
# - Output tokens: 89 [when editing the prompt with asking for exactly 3 sentences]
#
# Ratio = 89 / 47 ≈ 1.9x more
#
# **Answer:** 2-4x more

# %% [markdown]
# # Question 6

# %% [markdown]
# **Answer:** Use traditional task-based workflows for predictability and auditability
